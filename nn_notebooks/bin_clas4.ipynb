# %%
#Importing libraries

import os
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot
from pandas import DataFrame
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
"""
    DATA PREPARATION
      > Loading the dataset and splitting it into train, cross validation and test sets
      > The inputs are to be in the format of X.shape = (number_of_examples, number_of features)
      > The outputs are to be in the format of y.shape = (number_of_output_units, number_of_examples)
"""

N_SAMPLES = 1000
TEST_SIZE = 0.1
X, y = make_moons(n_samples = N_SAMPLES, noise=0.2, random_state=100)
X_tr, X_te, y_tr_t, y_te_t = train_test_split(X, y, test_size=TEST_SIZE, random_state=42)
y_tr_t = y_tr_t.reshape(y_tr_t.shape[0],1)
y_te_t = y_te_t.reshape(y_te_t.shape[0],1)
m_tr = y_tr_t.shape[0]
m_te = y_te_t.shape[0]
y_tr = y_tr_t.T
y_te = y_te_t.T


#Plotting the data

df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# %%
"""
    ACTIVATION FUNCTIONS
      > Defining the activation functions for the neural network. Note here that 
         the "tanh" activation function is implemented as "tang(x)"
"""

def sigmoid(x):
  return (1/(1+np.exp(-x)))
def relu(x):
    return np.maximum(0,x)
def tang(x):
  return np.tanh(x)

# %%
"""
    DEFINING UNITS AND ACTIVATION FUNCTIONS
      > Here the number of units in each layer and as a result the number of layers
         in our neural network is defined in a Python list "layer_dims"
      > Activation functions for each of the layers is also defined in the Python
         list "act_fn"
      > Note here that the length of act_fn is one less than that of the length of
         layer_dims
"""

layer_dims = [X_tr.shape[1],4,9,9,6,5,1]
act_fn = ["tang","tang","tang","tang","tang","sigmoid"]

# %%
"""
    INITIALISING THE PARAMETERS
      > The parameters of the neural network are 1.Weights and 2.Bias and these
         parameters are tweaked while training the network. 
      > Weights and bias for each of the layers(excluding the input layer) are
         initialised randomly and special weight initialisation techniques are
         used depending on the activation function of the layer.
      > Weights and bias are stored in the Python dictionary "parameters" and the
         weights of the ith layer are stored by keyword Wi and the bias in bi
      > Wi.shape = (number_of_units_in_(i-1)th_layer, number_of_units_in_(i)th_layer)
      > bi.shape = (number_of_units_in_(i)th_layer,1)
      > Arguments - layer_dims,act_fn
"""

def initialize_parameters(layer_dims,activation_fn):
  parameters = {}
  relu_init = 2
  tang_init = 1
  for i in range(1,len(layer_dims)):
    if activation_fn[i-1] is "relu":
      initi = relu_init
    if activation_fn[i-1] is "tang":
      initi = tang_init
    parameters["W"+str(i)] = np.random.randn(layer_dims[i],layer_dims[i-1])*np.sqrt(initi/layer_dims[i-1])
    parameters["b"+str(i)] = np.random.randn(layer_dims[i],1)*0.01
  return parameters

# %%
"""
    FORWARD PROPAGATION
      > The forward propagation makes a forward pass through the neural net. The
         outputs of all the layers are computed and then the activation
         for that particular layer is calculated.
      > The python dictionaries "outputs" are used to store the output of the dot
         product between the weights and the inputs and "activations" are used to
         store the activations of the outputs of that layer
      > The "outputs" contain keywords of the format Zi for the outputs of the ith
         layer and the "activations" contain keywords of the format Ai for the activations
         of the ith layer based on its activations as specified in "acts_fn"
      > The input data is also stored in A0 and is handy for back propagation
      > Arguments - Input_Data, parameters, activation_fn
"""

def forw_prop(X,parameters,activation_fn):
  outputs = {}
  activations = {}
  A_prev = X.T
  for i in range(1,len(layer_dims)):
    if activation_fn[i-1] is "relu":
      activ = relu
    if activation_fn[i-1] is "tang":
      activ = tang
    if activation_fn[i-1] is "sigmoid":
      activ = sigmoid
    outputs["Z" + str(i)] = np.dot(parameters["W" + str(i)],A_prev) + parameters["b"+str(i)]
    activations["A" + str(i)] = activ(outputs["Z" + str(i)])
    A_prev = activations["A" + str(i)]
  activations["A0"] = X.T
  return outputs,activations

# %%
"""
    COST FUNCTION
      > Cost function is calculated using the activations of the final layer of
         the network and the ground truth y
      > Arguments - activation, y, number_of_examples
"""

def cost_func(A,y,m_ex):
  cost = ((-1/m_ex)*(np.sum(np.sum((y*np.log(A)) + ((1-y)*np.log(1-A))))))
  return cost

# %%
"""
    GRADIENTS OF ACTIVATION FUNCTIONS
      > Here the gradients of the activation functions are defined.
      > This calculates the derivative of the activation of the ith layer to the
         outputs of the ith layer
      > Arguments - outputs Z
"""

def sigmoid_backward(z):
  grad_back = np.exp(-z)/np.square(1+np.exp(-z))
  return grad_back
def relu_backward(x):
  x[x<=0] = 0
  x[x>0] = 1
  return x
def tang_backward(x):
  return (1 - np.square(np.tanh(x)))

# %%
"""
    PREDICTIONS
      > The predictions for the outputs of the network are calculated given a
         threshold value for predicting the class of the input data according to
         the parameters learned by the network.
      > Arguments - A(Activations),threshold_for_classification
"""

def predict(A,threshold):
  predictions = np.zeros((A.shape))
  for i in range(0,A.shape[0]):
    for j in range(0,A.shape[1]):
      if A[i,j]>threshold:
        predictions[i,j]=1
      else:
        predictions[i,j]=0
  return predictions

# %%
def batch_grad_des(m_ex,alpha,grads,Y,activation_fn,outputs,activations,parameters):
  if activation_fn[len(layer_dims)-2] is "relu":
    backward = relu_backward
  if activation_fn[len(layer_dims)-2] is "tang":
    backward = tang_backward
  if activation_fn[len(layer_dims)-2] is "sigmoid":
    backward = sigmoid_backward
  grads["dA" + str(len(layer_dims)-1)] = (1/m_ex)*(((1-Y)/(1-activations["A" + str(len(layer_dims)-1)])) - (Y/activations["A" + str(len(layer_dims)-1)]))
  grads["dZ" + str(len(layer_dims)-1)] = grads["dA" + str(len(layer_dims)-1)]*backward(outputs["Z" + str(len(layer_dims)-1)])
  grads["dW" + str(len(layer_dims)-1)] = np.dot(grads["dZ" + str(len(layer_dims)-1)],activations["A" + str(len(layer_dims)-2)].T)
  grads["db" + str(len(layer_dims)-1)] = np.sum(grads["dZ" + str(len(layer_dims)-1)],axis=1,keepdims=True)
  for j in reversed(range(1,len(layer_dims)-1)):
    if activation_fn[j-1] is "relu":
      backward = relu_backward
    if activation_fn[j-1] is "tang":
      backward = tang_backward
    if activation_fn[j-1] is "sigmoid":
      backward = sigmoid_backward
    grads["dA" + str(j)] = np.dot(parameters["W" + str(j+1)].T,grads["dZ" + str(j+1)])
    grads["dZ" + str(j)] = grads["dA" + str(j)]*backward(outputs["Z" + str(j)])
    grads["dW" + str(j)] = np.dot(grads["dZ" + str(j)],activations["A" + str(j-1)].T)
    grads["db" + str(j)] = np.sum(grads["dZ" + str(j)],axis=1,keepdims=True)
  for k in range(1,len(layer_dims)):
    parameters["W" + str(k)] -= (alpha*(grads["dW" + str(k)]))
    parameters["b" + str(k)] -= (alpha*(grads["db" + str(k)]))
  return parameters

def gd_mom(m_ex,V_dict,grads,alpha,beta1,Y,activation_fn,outputs,activations,parameters):
  if activation_fn[len(layer_dims)-2] is "relu":
    backward = relu_backward
  if activation_fn[len(layer_dims)-2] is "tang":
    backward = tang_backward
  if activation_fn[len(layer_dims)-2] is "sigmoid":
    backward = sigmoid_backward
  grads["dA" + str(len(layer_dims)-1)] = (1/m_ex)*(((1-Y)/(1-activations["A" + str(len(layer_dims)-1)])) - (Y/activations["A" + str(len(layer_dims)-1)]))
  grads["dZ" + str(len(layer_dims)-1)] = grads["dA" + str(len(layer_dims)-1)]*backward(outputs["Z" + str(len(layer_dims)-1)])
  grads["dW" + str(len(layer_dims)-1)] = np.dot(grads["dZ" + str(len(layer_dims)-1)],activations["A" + str(len(layer_dims)-2)].T)
  grads["db" + str(len(layer_dims)-1)] = np.sum(grads["dZ" + str(len(layer_dims)-1)],axis=1,keepdims=True)
  for j in reversed(range(1,len(layer_dims)-1)):
    if activation_fn[j-1] is "relu":
      backward = relu_backward
    if activation_fn[j-1] is "tang":
      backward = tang_backward
    if activation_fn[j-1] is "sigmoid":
      backward = sigmoid_backward
    grads["dA" + str(j)] = np.dot(parameters["W" + str(j+1)].T,grads["dZ" + str(j+1)])
    grads["dZ" + str(j)] = grads["dA" + str(j)]*backward(outputs["Z" + str(j)])
    grads["dW" + str(j)] = np.dot(grads["dZ" + str(j)],activations["A" + str(j-1)].T)
    grads["db" + str(j)] = np.sum(grads["dZ" + str(j)],axis=1,keepdims=True)
  for h in range(1,len(layer_dims)):
    V_dict["Vdw" + str(h)] = (beta1*V_dict["Vdw" + str(h)]) + ((1-beta1)*grads["dW" + str(h)])
    V_dict["Vdb" + str(h)] = (beta1*V_dict["Vdb" + str(h)]) + ((1-beta1)*grads["db" + str(h)])
  for g in range(1,len(layer_dims)):
    parameters["W" + str(g)] -= (alpha*(V_dict["Vdw" + str(g)]))
    parameters["b" + str(g)] -= (alpha*(V_dict["Vdb" + str(g)]))
  return parameters


def rms_prop(m_ex,S_dict,grads,epsilon,alpha,beta2,Y,activation_fn,outputs,activations,parameters):
  if activation_fn[len(layer_dims)-2] is "relu":
    backward = relu_backward
  if activation_fn[len(layer_dims)-2] is "tang":
    backward = tang_backward
  if activation_fn[len(layer_dims)-2] is "sigmoid":
    backward = sigmoid_backward
  grads["dA" + str(len(layer_dims)-1)] = (1/m_ex)*(((1-Y)/(1-activations["A" + str(len(layer_dims)-1)])) - (Y/activations["A" + str(len(layer_dims)-1)]))
  grads["dZ" + str(len(layer_dims)-1)] = grads["dA" + str(len(layer_dims)-1)]*backward(outputs["Z" + str(len(layer_dims)-1)])
  grads["dW" + str(len(layer_dims)-1)] = np.dot(grads["dZ" + str(len(layer_dims)-1)],activations["A" + str(len(layer_dims)-2)].T)
  grads["db" + str(len(layer_dims)-1)] = np.sum(grads["dZ" + str(len(layer_dims)-1)],axis=1,keepdims=True)
  for j in reversed(range(1,len(layer_dims)-1)):
    if activation_fn[j-1] is "relu":
      backward = relu_backward
    if activation_fn[j-1] is "tang":
      backward = tang_backward
    if activation_fn[j-1] is "sigmoid":
      backward = sigmoid_backward
    grads["dA" + str(j)] = np.dot(parameters["W" + str(j+1)].T,grads["dZ" + str(j+1)])
    grads["dZ" + str(j)] = grads["dA" + str(j)]*backward(outputs["Z" + str(j)])
    grads["dW" + str(j)] = np.dot(grads["dZ" + str(j)],activations["A" + str(j-1)].T)
    grads["db" + str(j)] = np.sum(grads["dZ" + str(j)],axis=1,keepdims=True)
  for h in range(1,len(layer_dims)):
    S_dict["Sdw" + str(h)] = (beta2*S_dict["Sdw" + str(h)]) + ((1-beta2)*np.square(grads["dW" + str(h)]))
    S_dict["Sdb" + str(h)] = (beta2*S_dict["Sdb" + str(h)]) + ((1-beta2)*np.square(grads["db" + str(h)]))
  for g in range(1,len(layer_dims)):
    parameters["W" + str(g)] -= ((alpha*grads["dW" + str(g)])/(np.sqrt(S_dict["Sdw" + str(g)]) + epsilon))
    parameters["b" + str(g)] -= ((alpha*grads["db" + str(g)])/(np.sqrt(S_dict["Sdb" + str(g)]) + epsilon))
  return parameters


def adam(t,m_ex,epsilon,grads,V_dict,S_dict,alpha,beta1,beta2,Y,activation_fn,outputs,activations,parameters):
  S_dict_corr = {}
  V_dict_corr = {}
  if activation_fn[len(layer_dims)-2] is "relu":
    backward = relu_backward
  if activation_fn[len(layer_dims)-2] is "tang":
    backward = tang_backward
  if activation_fn[len(layer_dims)-2] is "sigmoid":
    backward = sigmoid_backward
  grads["dA" + str(len(layer_dims)-1)] = (1/m_ex)*(((1-Y)/(1-activations["A" + str(len(layer_dims)-1)])) - (Y/activations["A" + str(len(layer_dims)-1)]))
  grads["dZ" + str(len(layer_dims)-1)] = grads["dA" + str(len(layer_dims)-1)]*backward(outputs["Z" + str(len(layer_dims)-1)])
  grads["dW" + str(len(layer_dims)-1)] = np.dot(grads["dZ" + str(len(layer_dims)-1)],activations["A" + str(len(layer_dims)-2)].T)
  grads["db" + str(len(layer_dims)-1)] = np.sum(grads["dZ" + str(len(layer_dims)-1)],axis=1,keepdims=True)
  for j in reversed(range(1,len(layer_dims)-1)):
    if activation_fn[j-1] is "relu":
      backward = relu_backward
    if activation_fn[j-1] is "tang":
      backward = tang_backward
    if activation_fn[j-1] is "sigmoid":
      backward = sigmoid_backward
    grads["dA" + str(j)] = np.dot(parameters["W" + str(j+1)].T,grads["dZ" + str(j+1)])
    grads["dZ" + str(j)] = grads["dA" + str(j)]*backward(outputs["Z" + str(j)])
    grads["dW" + str(j)] = np.dot(grads["dZ" + str(j)],activations["A" + str(j-1)].T)
    grads["db" + str(j)] = np.sum(grads["dZ" + str(j)],axis=1,keepdims=True)
  for h in range(1,len(layer_dims)):
    V_dict["Vdw" + str(h)] = (beta1*V_dict["Vdw" + str(h)]) + ((1-beta1)*grads["dW" + str(h)])
    V_dict["Vdb" + str(h)] = (beta1*V_dict["Vdb" + str(h)]) + ((1-beta1)*grads["db" + str(h)])
  for c in range(1,len(layer_dims)):
    S_dict["Sdw" + str(c)] = (beta2*S_dict["Sdw" + str(c)]) + ((1-beta2)*np.square(grads["dW" + str(c)]))
    S_dict["Sdb" + str(c)] = (beta2*S_dict["Sdb" + str(c)]) + ((1-beta2)*np.square(grads["db" + str(c)]))
  for n in range(1,len(layer_dims)):
    S_dict_corr["Sdw" + str(n)] = S_dict["Sdw" + str(n)]/(1 - np.power(beta2,t))
    S_dict_corr["Sdb" + str(n)] = S_dict["Sdb" + str(n)]/(1 - np.power(beta2,t))
    V_dict_corr["Vdw" + str(n)] = V_dict["Vdw" + str(n)]/(1 - np.power(beta1,t))
    V_dict_corr["Vdb" + str(n)] = V_dict["Vdb" + str(n)]/(1 - np.power(beta1,t))
  for g in range(1,len(layer_dims)):
    parameters["W" + str(g)] -= ((alpha*V_dict["Vdw" + str(g)])/(np.sqrt(S_dict_corr["Sdw" + str(g)]) + epsilon))
    parameters["b" + str(g)] -= ((alpha*V_dict["Vdb" + str(g)])/(np.sqrt(S_dict_corr["Sdb" + str(g)]) + epsilon))
  return parameters

# %%
"""
    FIT
      > This function is used to train the network on training data and the weights
         are updated by backpropagation through Optimization functions (Gradient descent,RMSprop,Adam)
      > Returns "costs" a Python list consisting of all the costs through the iterations
         and the updated "parameters" dictionary
      > Returns the "master_cache" which contains the values of outputs, activations,
         parameters throughout the training period of the format "master_cache["Z" + str(j) + str(_) + str(i)]
         returns the outputs of the jth layer in the ith iteration of training"
      > Arguments - X(train),Y(train),number_of_training_examples,number_of_iterations,
         learning_rate,parameters,activation_fn,print_cost(True/False),callback
"""

def fit(X,Y,m_ex,num_iterations,alpha,optim,params,activation_fn,print_cost,callback=None):
  costs = []
  #master_cache = {}
  p = 0
  V_dict = {}
  S_dict = {}
  for k in range(1,len(layer_dims)):
    V_dict["Vdw" + str(k)] = np.zeros(params["W" + str(k)].shape)
    V_dict["Vdb" + str(k)] = np.zeros(params["b" + str(k)].shape)
    S_dict["Sdw" + str(k)] = np.zeros(params["W" + str(k)].shape)
    S_dict["Sdb" + str(k)] = np.zeros(params["b" + str(k)].shape)
  for i in range(1,num_iterations+1):
    grads = {}
    outputs,activations = forw_prop(X,params,activation_fn)
    #for o in range(1,len(layer_dims)):
      #master_cache["Z" + str(o) + str(_) + str(i)] = outputs["Z" + str(o)]
      #master_cache["A" + str(o) + str(_) + str(i)] = activations["A" + str(o)]
    cost = cost_func(activations["A" + str(len(layer_dims)-1)],Y,m_ex)
    costs.append(cost)
    predictions = predict(activations["A" + str(len(layer_dims)-1)],0.5)
    if optim == "Batch Gradient Descent":
      params = batch_grad_des(m_ex,alpha,grads,Y,activation_fn,outputs,activations,params)
    if optim == "Momentum":
      params = gd_mom(m_ex,V_dict,grads,alpha,0.9,Y,activation_fn,outputs,activations,params)
    if optim == "RMSprop":
      params = rms_prop(m_ex,S_dict,grads,1e-8,alpha,0.999,Y,activation_fn,outputs,activations,params)
    if optim == "Adam":
      params = adam(i,m_ex,1e-8,grads,V_dict,S_dict,alpha,0.9,0.999,Y,activation_fn,outputs,activations,params)
    if ((print_cost is True) and (i%10==0)):
        print("Cost after iteration " + str(i) + " is " + str(costs[p]) + " -------- " + "Training accuracy = " + str(float(np.mean(predictions==Y,axis=1))*100))
    p = p+1
    if(i % 4 == 0):
      if(callback is not None):
                callback(i, params)
  return costs, params#, master_cache

# %%
"""
    PRECISION RECALL AND F1 SCORE
      > Function is defined to calculate the precision, recall and F1 scores of the test and
         cross validation data
      > Returns the precision, recall and F1 score
      > Arguments - Predictions_of_the_final_activation, y(ground_truth)
"""

def prec_rec(A,y):
  tp = 0
  fp = 0
  fn = 0
  for i in range(0,y.shape[1]):
    if ((A[0,i]==1)and(y[0,i]==1)):
      tp = tp+1
    if ((A[0,i]==1)and(y[0,i]==0)):
      fp = fp+1
    if (A[0,i]==0)and(y[0,i]==1):
      fn = fn+1
  prec = tp/(tp+fp)
  rec = tp/(tp+fn)
  f1 = (2*prec*rec)/(prec+rec)
  return prec,rec,f1

# %%
"""
    PERFORMANCE ON TEST AND CROSS VALIDATION DATA
      > This function evaluates the performance of the learning algorithm on test
         and cross validation data
      > Returns the accuracy, precision, recall and F1 score of test and cross validation
         datasets
      > Arguments - X,y,trained_parameters,print_values(True/False)
"""

def cross_val(X,y,params_tr,print_values):
  out_cv,act_cv = forw_prop(X,params_tr,act_fn)
  predictions_cv = predict(act_cv["A" + str(len(layer_dims)-1)],0.5)
  accu_cv = float(np.mean(predictions_cv==y,axis=1))*100
  prec_cv,rec_cv,f1_cv = prec_rec(predictions_cv,y)
  if print_values is True:
    print("CROSS VAL RESULTS: ")
    print("Cross val accuracy = " + str(accu_cv))
    print("Precision: " + str(prec_cv))
    print("Recall: " + str(rec_cv))
    print("F1 score: " + str(f1_cv))
    print('\n')
    print('\n')
  return accu_cv,prec_cv,rec_cv,f1_cv
def test(X,y,params_tr,print_values):
  out_te,act_te = forw_prop(X,params_tr,act_fn)
  predictions_te = predict(act_te["A" + str(len(layer_dims)-1)],0.5)
  accu_te = float(np.mean(predictions_te==y,axis=1))*100
  prec_te,rec_te,f1_te = prec_rec(predictions_te,y)
  if print_values is True:
    print("TEST RESULTS: ")
    print("Testing accuracy = " + str(accu_te))
    print("Precision: " + str(prec_te))
    print("Recall: " + str(rec_te))
    print("F1 score: " + str(f1_te))
    print('\n')
    print('\n')
  return accu_te,prec_te,rec_te,f1_te

# %%
#Training the network

parameters_dat = initialize_parameters(layer_dims,act_fn)
costs,parameters = fit(X_tr,y_tr,m_tr,1000,0.05,"Momentum",parameters_dat,act_fn,print_cost=True)
# Out:
# Cost after iteration 10 is 0.7033470365153597 -------- Training accuracy = 34.77777777777778
# Cost after iteration 20 is 0.6613739285622019 -------- Training accuracy = 81.22222222222221
# Cost after iteration 30 is 0.6262313538232279 -------- Training accuracy = 76.88888888888889
# Cost after iteration 40 is 0.5975217213499806 -------- Training accuracy = 76.33333333333333
# Cost after iteration 50 is 0.570495232496896 -------- Training accuracy = 76.88888888888889
# Cost after iteration 60 is 0.5442076250206127 -------- Training accuracy = 77.0
# Cost after iteration 70 is 0.5187229491589976 -------- Training accuracy = 78.0
# Cost after iteration 80 is 0.4938993946663801 -------- Training accuracy = 78.55555555555556
# Cost after iteration 90 is 0.46950581315061646 -------- Training accuracy = 80.0
# Cost after iteration 100 is 0.44541058807372524 -------- Training accuracy = 81.44444444444444
# Cost after iteration 110 is 0.42160001644331674 -------- Training accuracy = 83.0
# Cost after iteration 120 is 0.3983484181012421 -------- Training accuracy = 85.0
# Cost after iteration 130 is 0.37646191350846775 -------- Training accuracy = 86.11111111111111
# Cost after iteration 140 is 0.3571467887152247 -------- Training accuracy = 87.1111111111111
# Cost after iteration 150 is 0.3413340952575664 -------- Training accuracy = 88.0
# Cost after iteration 160 is 0.32893829622572224 -------- Training accuracy = 88.1111111111111
# Cost after iteration 170 is 0.31918092477200677 -------- Training accuracy = 87.8888888888889
# Cost after iteration 180 is 0.31134401726090977 -------- Training accuracy = 88.1111111111111
# Cost after iteration 190 is 0.3048487430492796 -------- Training accuracy = 88.1111111111111
# Cost after iteration 200 is 0.29917688364599837 -------- Training accuracy = 88.44444444444444
# Cost after iteration 210 is 0.29391963218071687 -------- Training accuracy = 88.77777777777777
# Cost after iteration 220 is 0.2887790086723529 -------- Training accuracy = 88.88888888888889
# Cost after iteration 230 is 0.28353587927670915 -------- Training accuracy = 89.11111111111111
# Cost after iteration 240 is 0.27803102127925877 -------- Training accuracy = 89.55555555555556
# Cost after iteration 250 is 0.27215272866385054 -------- Training accuracy = 89.66666666666666
# Cost after iteration 260 is 0.2658293294860016 -------- Training accuracy = 89.66666666666666
# Cost after iteration 270 is 0.25902588943713795 -------- Training accuracy = 90.11111111111111
# Cost after iteration 280 is 0.25174199382332946 -------- Training accuracy = 90.77777777777779
# Cost after iteration 290 is 0.24400863934719028 -------- Training accuracy = 90.88888888888889
# Cost after iteration 300 is 0.23588287230114263 -------- Training accuracy = 91.33333333333333
# Cost after iteration 310 is 0.2274408021590231 -------- Training accuracy = 91.66666666666666
# Cost after iteration 320 is 0.21877100622036058 -------- Training accuracy = 91.88888888888889
# Cost after iteration 330 is 0.20996991865965148 -------- Training accuracy = 92.33333333333333
# Cost after iteration 340 is 0.20113935719670614 -------- Training accuracy = 93.0
# Cost after iteration 350 is 0.19238509804008622 -------- Training accuracy = 93.33333333333333
# Cost after iteration 360 is 0.1838148700697096 -------- Training accuracy = 93.44444444444444
# Cost after iteration 370 is 0.17553445070432103 -------- Training accuracy = 93.66666666666667
# Cost after iteration 380 is 0.1676416202426188 -------- Training accuracy = 94.22222222222221
# Cost after iteration 390 is 0.16021900857823015 -------- Training accuracy = 94.22222222222221
# Cost after iteration 400 is 0.15332771785011498 -------- Training accuracy = 94.44444444444444
# Cost after iteration 410 is 0.14700362205367498 -------- Training accuracy = 94.77777777777779
# Cost after iteration 420 is 0.14125736226034297 -------- Training accuracy = 94.88888888888889
# Cost after iteration 430 is 0.13607772239242197 -------- Training accuracy = 95.33333333333334
# Cost after iteration 440 is 0.13143704093765993 -------- Training accuracy = 95.55555555555556
# Cost after iteration 450 is 0.12729706065742533 -------- Training accuracy = 95.55555555555556
# Cost after iteration 460 is 0.12361404019640888 -------- Training accuracy = 95.66666666666667
# Cost after iteration 470 is 0.12034260883011373 -------- Training accuracy = 95.77777777777777
# Cost after iteration 480 is 0.11743835947478105 -------- Training accuracy = 95.77777777777777
# Cost after iteration 490 is 0.11485942200049293 -------- Training accuracy = 95.88888888888889
# Cost after iteration 500 is 0.11256730395934914 -------- Training accuracy = 96.0
# Cost after iteration 510 is 0.11052723944426886 -------- Training accuracy = 96.11111111111111
# Cost after iteration 520 is 0.10870822298378502 -------- Training accuracy = 96.22222222222221
# Cost after iteration 530 is 0.1070828523208392 -------- Training accuracy = 96.22222222222221
# Cost after iteration 540 is 0.10562706499754616 -------- Training accuracy = 96.33333333333334
# Cost after iteration 550 is 0.10431982552951413 -------- Training accuracy = 96.33333333333334
# Cost after iteration 560 is 0.10314279959185142 -------- Training accuracy = 96.33333333333334
# Cost after iteration 570 is 0.1020800372130905 -------- Training accuracy = 96.33333333333334
# Cost after iteration 580 is 0.10111767714865673 -------- Training accuracy = 96.33333333333334
# Cost after iteration 590 is 0.10024367821653773 -------- Training accuracy = 96.33333333333334
# Cost after iteration 600 is 0.09944757941821687 -------- Training accuracy = 96.33333333333334
# Cost after iteration 610 is 0.09872028834315419 -------- Training accuracy = 96.44444444444444
# Cost after iteration 620 is 0.09805389608794643 -------- Training accuracy = 96.44444444444444
# Cost after iteration 630 is 0.09744151631575407 -------- Training accuracy = 96.55555555555554
# Cost after iteration 640 is 0.09687714587611276 -------- Training accuracy = 96.55555555555554
# Cost after iteration 650 is 0.09635554443150482 -------- Training accuracy = 96.55555555555554
# Cost after iteration 660 is 0.09587213068905934 -------- Training accuracy = 96.55555555555554
# Cost after iteration 670 is 0.09542289304822126 -------- Training accuracy = 96.55555555555554
# Cost after iteration 680 is 0.09500431270911713 -------- Training accuracy = 96.55555555555554
# Cost after iteration 690 is 0.09461329751914052 -------- Training accuracy = 96.55555555555554
# Cost after iteration 700 is 0.09424712505478683 -------- Training accuracy = 96.55555555555554
# Cost after iteration 710 is 0.09390339363604691 -------- Training accuracy = 96.55555555555554
# Cost after iteration 720 is 0.09357998014955582 -------- Training accuracy = 96.66666666666667
# Cost after iteration 730 is 0.09327500371415375 -------- Training accuracy = 96.66666666666667
# Cost after iteration 740 is 0.09298679435971628 -------- Training accuracy = 96.77777777777777
# Cost after iteration 750 is 0.09271386600879512 -------- Training accuracy = 96.77777777777777
# Cost after iteration 760 is 0.0924548931527503 -------- Training accuracy = 96.66666666666667
# Cost after iteration 770 is 0.09220869070164876 -------- Training accuracy = 96.66666666666667
# Cost after iteration 780 is 0.091974196562146 -------- Training accuracy = 96.66666666666667
# Cost after iteration 790 is 0.0917504565615879 -------- Training accuracy = 96.77777777777777
# Cost after iteration 800 is 0.09153661139123166 -------- Training accuracy = 96.77777777777777
# Cost after iteration 810 is 0.09133188528814093 -------- Training accuracy = 96.77777777777777
# Cost after iteration 820 is 0.0911355762151484 -------- Training accuracy = 96.77777777777777
# Cost after iteration 830 is 0.09094704733231856 -------- Training accuracy = 96.77777777777777
# Cost after iteration 840 is 0.09076571958244845 -------- Training accuracy = 96.88888888888889
# Cost after iteration 850 is 0.09059106523805514 -------- Training accuracy = 97.0
# Cost after iteration 860 is 0.09042260227864397 -------- Training accuracy = 97.0
# Cost after iteration 870 is 0.0902598894853544 -------- Training accuracy = 97.0
# Cost after iteration 880 is 0.09010252215579465 -------- Training accuracy = 97.0
# Cost after iteration 890 is 0.08995012835537296 -------- Training accuracy = 97.0
# Cost after iteration 900 is 0.08980236563303978 -------- Training accuracy = 97.0
# Cost after iteration 910 is 0.08965891813933341 -------- Training accuracy = 97.0
# Cost after iteration 920 is 0.08951949409321062 -------- Training accuracy = 97.0
# Cost after iteration 930 is 0.08938382355153378 -------- Training accuracy = 97.0
# Cost after iteration 940 is 0.08925165644144475 -------- Training accuracy = 97.0
# Cost after iteration 950 is 0.08912276082132943 -------- Training accuracy = 97.0
# Cost after iteration 960 is 0.08899692134078434 -------- Training accuracy = 97.0
# Cost after iteration 970 is 0.08887393787404527 -------- Training accuracy = 97.0
# Cost after iteration 980 is 0.08875362430481994 -------- Training accuracy = 97.0
# Cost after iteration 990 is 0.08863580744345487 -------- Training accuracy = 97.0
# Cost after iteration 1000 is 0.0885203260599355 -------- Training accuracy = 97.0

# %%
#cross_val(X_cv,y_cv,parameters,print_values=True)
test(X_te,y_te,parameters,print_values=True)
# Out:
# TEST RESULTS:
# Testing accuracy = 99.0
# Precision: 0.9787234042553191
# Recall: 1.0
# F1 score: 0.989247311827957
# (99.0, 0.9787234042553191, 1.0, 0.989247311827957)

# %%
#Plotting Cost vs Number of Iterations

import matplotlib.pyplot as plt
itera = np.arange(1,len(costs)+1,1)
plt.xlabel('Number of iterations')
plt.ylabel('Cost')
plt.title('Cost Function variation')
plt.plot(itera,costs)

# %%
#Decision Boundary Visualisation helper functions
#Remember to set the path to which the graphs should be stored in "OUTPUT_DIR"

sns.set_style("whitegrid")
GRID_X_START = -1.5
GRID_X_END = 2.5
GRID_Y_START = -1.0
GRID_Y_END = 2
OUTPUT_DIR = "/content/drive/My Drive/Colab Notebooks/momentum"
grid = np.mgrid[GRID_X_START:GRID_X_END:100j,GRID_X_START:GRID_Y_END:100j]
grid_2d = grid.reshape(2,-1)
XX, YY = grid
def make_plot(X, y, plot_name, file_name=None, XX=None, YY=None, preds=None, dark=False):
    if (dark):
        plt.style.use('dark_background')
    else:
        sns.set_style("whitegrid")
    plt.figure(figsize=(16,12))
    axes = plt.gca()
    axes.set(xlabel="$X_1$", ylabel="$X_2$")
    plt.title(plot_name, fontsize=30)
    plt.subplots_adjust(left=0.20)
    plt.subplots_adjust(right=0.80)
    if(XX is not None and YY is not None and preds is not None):
        plt.contourf(XX, YY, preds.reshape(XX.shape), 25, alpha = 1, cmap=cm.Spectral)
        plt.contour(XX, YY, preds.reshape(XX.shape), levels=[.5], cmap="Greys", vmin=0, vmax=.6)
    plt.scatter(X[:, 0], X[:, 1], c=y.ravel(), s=40, cmap=plt.cm.Spectral, edgecolors='black')
    if(file_name):
        plt.savefig(file_name)
        plt.close()
import os
def callback_numpy_plot(index, init_params):
    plot_title = "Iteration {:05}".format(index)
    file_name = "numpy_model_{:05}.png".format(index//4)
    file_path = os.path.join(OUTPUT_DIR, file_name)
    out,act = forw_prop(np.transpose(grid_2d),init_params,act_fn)
    prediction_probs = act["A" + str(len(layer_dims)-1)]
    prediction_probs = prediction_probs.reshape(prediction_probs.shape[1], 1)
    make_plot(X_te, y_te, plot_title, file_name=file_path, XX=XX, YY=YY, preds=prediction_probs, dark=True)

# %%
#Decision Boundary Visualisation

layer_dims_vis = layer_dims
layer_dims_vis[0] = 2
parameters_dat = initialize_parameters(layer_dims_vis,act_fn)
_,params_values = fit(X_tr, y_tr, m_tr, 1000, 0.05,"Momentum",parameters_dat,activation_fn = act_fn,print_cost=False,callback = callback_numpy_plot)

# %%
#Get the final Decision Boundary at the end of training evaluated on the test set 

out,act = forw_prop(np.transpose(grid_2d),params_values,act_fn)
prediction_probs_np = act["A" + str(len(layer_dims)-1)]
prediction_probs_np = prediction_probs_np.reshape(prediction_probs_np.shape[1], 1)
make_plot(X_te, y_te, "Final Iteration", file_name=None, XX=XX, YY=YY, preds=prediction_probs_np, dark=True)
